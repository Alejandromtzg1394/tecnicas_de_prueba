# %% [markdown]
# # Estructura de datos: Diccionarios
# - ### Los diccionarios en Python son una estructura de datos que permite almacenar su contenido en forma de clave y valor.
# - ### Son dinámicos: se pueden añadir o eliminar elementos.
# - ### Son indexados a través de la clave.
# - ### Son anidados: un diccionario puede contener a otro diccionario en su campo valor.

# %% [markdown]
# ### Definición de diccionarios

# %%
datos1 = {'nombre' : 'Juan', 'edad' : 22, 'calficaciones':[10,8,9]}

# %%
datos1

# %% [markdown]
# ### Otra manera de definir diccionarios

# %%
datos2 = dict(nombre='Pedro', edad=28)

# %%
datos2

# %% [markdown]
# ### Diccionarios anidados

# %%
datos3 = {'nombre' : 'Juan', 'edad' : 22, 'calificaciones': {'matematicas': 10, 'español': 8, 'biología': 9}}

# %%
datos3

# %% [markdown]
# # Combinar datos

# %%
registro = {1:datos1,2:datos2}

# %%
registro

# %% [markdown]
# # Acceder a los datos

# %%
datos3 = {'nombre' : 'Juan', 'edad' : 22, 'calificaciones': {'matematicas': 10, 'español': 8, 'biología': 9}}
datos3['calificaciones']['español']

# %% [markdown]
# # Asignar valores

# %%
datos3 = {'nombre' : 'Juan', 'edad' : 22, 'calificaciones': {'matematicas': 10, 'español': 8, 'biología': 9}}
print(datos3)

datos3['nombre']= 'Juan Carlos' 
print(datos3)

# %% [markdown]
# # Eliminar datos

# %%
datos3 = {'nombre' : 'Juan', 'edad' : 22, 'calificaciones': {'matematicas': 10, 'español': 8, 'biología': 9}}
print(datos3)

del datos3['edad']
print(datos3)

# %% [markdown]
# # Recuperar valores

# %%
datos3 = {'nombre' : 'Juan', 'edad' : 22, 'calificaciones': {'matematicas': 10, 'español': 8, 'biología': 9}}
nombre = datos3['nombre']
print(nombre)

nombre = datos3.get('nombre')
print(nombre)

# %% [markdown]
# # Membresia

# %%
registro = { 'María': { 'edad' : 22, 'calificaciones': {'matematicas': 10, 'español': 8, 'biología': 9}}, 
             'Juan':  { 'edad' : 28, 'calificaciones': {'matematicas': 9, 'español': 9, 'biología': 9}}, 
             'Pedro': { 'edad' : 28, 'calificaciones': {'matematicas': 9, 'español': 9, 'biología': 9}}, 
             }

'María' in registro

# %%
nombre = 'María'
if nombre in registro:
    print("Existe el registro de {nombre}")

# %%
registro['Pedro']

# %% [markdown]
# # Conteo

# %%
s = "Hola mundo hola todos"
dat={}
for c in s:
    if c in dat:
        dat[c] = dat[c] + 1
    else:
        dat[c] = 1

# %%
print(dat)

# %% [markdown]
# # Tipo de dato: Counter
# - ### Counter es una subclase de dict que está especialmente diseñada para contar objetos hash en Python.
# - ### Es un diccionario que asigna objetos como claves y un contador como valores

# %%
from collections import Counter
cnt =  Counter(s)
cnt

# %%
from collections import Counter
caracteres =  Counter()
for c in s:
       caracteres[c] +=1

caracteres

# %%
from collections import Counter

inventario = Counter(
    manzanas=10,
    naranjas=15,
    papas=0,
    jitomates=5
)

# %%
inventario

# %%
print(list(inventario.keys()))
print(list(inventario.values()))

# %% [markdown]
# # Instalar el paquete matplotlib desde la terminal del sistema en el ambiente TPS
# # $> conda install matplotlib

# %%
import matplotlib.pyplot as plt

k=list(caracteres.keys())
v=list(caracteres.values())
print(k,v)
x_pos = [i for i, _ in enumerate(k)]
plt.xticks(x_pos, k)
plt.bar(x_pos, v, align='center')

# %%
caracteres.update("ooooooooo sssssss")
caracteres

# %%
# los 3 mas comunes en la colección
caracteres.most_common(3)

# %%
# iterar en la coleccion de datos 
for i in caracteres.items():
    print(i)

# %% [markdown]
# # Estructura de datos: set
# - ### Los elementos de un set son único,  no puede haber elementos duplicados.
# - ### Los set son desordenados, no mantienen el orden de cuando son declarados.
# - ### Sus elementos deben ser inmutables.

# %%
A = set(['aaa', '1', 'b', 3, '4', 'c', 'a','a','a'])
B = set(['aa', '1', 'bb', 3, '5', 'c', 'a'])

# %%
A

# %%
B

# %%
AA = set("anita lava la tina")

# %%
AA

# %%
A.union(B)

# %%
A.intersection(B)

# %% [markdown]
# # Tuplas
# - ### Permite almacenar datos similar  a las listas, los elementos son inmutables (no pueden cambiar).
# - ### No pueden ser modificadas una vez declaradas

# %%
tupla = (1, 2, 3)
tupla2 = 5, 6, 7

print(type(tupla)) #<class 'tuple'>
print(type(tupla2)) #<class 'tuple'>
print(tupla)       #(1, 2, 3)
print(tupla2)       #(1, 2, 3)

# %%
# Inmutables

#tupla[0] = 5 # Error! TypeError

tupla[0] = 5

# %%
# Se puede iterar

tupla = (1, 2, 3)
for t in tupla:
    print(t) #1, 2, 3

# %%
# Asignar elementos a N variables
l = (10, 20, 30)
x, y, z = l
print(x, y, z)

# %% [markdown]
# # Ejercicio
#
# - ### Hacer un programa que simule un carrito de compras, esto es, solicitar al usuario productos que quiere comprar y la cantidad.
#     - ### Solicitar por medio del teclado el nombre del producto y la cantidad.
#     - ### Almacenar los datos en un diccionario.
#     - ### El programa termina hasta que el usuario teclee la palabra FIN.
#     - ### Al finalizar la captura, imprimir el contenido del carrito de compras en la pantalla.

# %% [markdown]
# # Gutenberg project
# http://www.gutenberg.org

# %% [markdown]
# # Lectura de archivos

# %%
k = 0
f = open("./data/celestina.txt", 'r', encoding='utf8')
text = f.readlines()
print(text)
f.close()
# Out:
# ['\n', 'LA CELESTINA\n', '\n', 'por\n', '\n', 'Fernando de Rojas\n', '\n', '(Edicion y Notas de Robert S. Rudder)\n', '\n', 'Copyright 1998 R. S. Rudder\n', '\n', '\n', '\n', '\n', 'I. Introduccion\n', '\n', 'II. La Celestina\n', '\n', 'III Glosario y Notas\n', '\n', '\n', '\n', '\n', 'INTRODUCCION\n', '\n', 'Si bien es cierto que "La Celestina" nos deja con muchas dudas\n', 'sobre la personalidad de los personajes, esta misma vaguedad hace\n', 'que la obra parezca mas realista, permitiendo incluso una lectura\n', 'moderna. Poco sabemos tambien sobre la autoria de la obra; sabemos\n', 'que Fernando de Rojas, el unico autor conocido, fue un judio\n', 'converso, nacido en Montalban, y que estudio en la Universidad de\n', 'Salamanca. Despues de haber escrito esta obra maestra en su\n', 'juventud, simplemente desaparecio de la escena literaria: fue a\n', 'Talavera para ejercer el oficio de abogado, y alli murio en 1541.\n', '\n', 'El lugar de la accion de la obra no tiene semejanza geografica\n', 'especifica con ningun pueblo de Espana.  Quedan tambien como meras\n', 'sombras varios grupos de personajes (la muchedumbre que asiste al\n', 'ajusticiamiento de Sempronio y Parmeno; los vecinos congregados\n', 'alrededor de Pleberio cuando este da su discurso final). Y aunque\n', 'las descripciones fisicas de los personajes centrales de la obra\n', 'no son nada mas que bosquejos, hay una gran profundidad en sus\n', 'personalidades.  Los dos personajes centrales cuyas vidas y\n', 'destinos se enlazan apasionadamente, Calisto y Melibea, comparten\n', 'una historia que se extiende mas alla de los confines de "La\n', 'Celestina".  Desde sus primeras palabras vemos que se han conocido\n', 'antes del comienzo de la obra:  "en tan conueniente lugar que mi\n', 'secreto dolor manifestarte pudiesse.  sin dubda encomparablemente\n', 'es mayor tal galardon que el seruicio: sacrificio: deuocion e\n', 'obras pias que por este lugar alcanzar tengo yo a dios ofrescido."\n', 'Estas vidas que se mueven tanto dentro como fuera de la obra,\n', 'encontraran su eco mas de cien anos despues en el arte de\n', 'Velazquez donde hay figuras que aparecen dentro y fuera de la\n', 'pintura.\n', '\n', 'Para esta edicion electronica se han utilizado las cuatro\n', 'siguientes versiones de "La Celestina":\n', '\n', '1. "Comedia de Calisto y Melibea", Burgos, 1499.  16 actos.\n', 'Facsimile.\n', '\n', '2. "Comedia de Calisto y Melibea", Toledo, 1500.  16 actos,\n', 'Facsimile. Esta edicion tiene una carta del "autor a un su amigo",\n', 'donde dice que encontro el primer acto, y que escribio los demas\n', 'actos en quince dias de vacaciones.  Tambien hay versos de "El\n', 'autor escusandose de su yerro en esta obra que escriuio..." los\n', 'cuales son un acrostico que revela lo siguiente: "El bachjller\n', 'fernando de royas acabo la comedia de calysto y melybea y fve\n', 'nascjdo en la puebla de montalvan."\n', '\n', '3.  "Comedia de Calisto y Melibea", Sevilla, 1501.  Edicion de\n', 'Foulche-Delbosc (1900).  Semejante a la edicion de Toledo, 1500,\n', 'con unas variaciones en la "carta" y en los primeros versos.\n', '\n', '4. "Tragicomedia de Calisto y Melibea", Valencia, 1514.  21 actos\n', 'y otras interpolaciones.  Facsimile.\n', '\n', 'He mantenido la ortografia y puntuacion de los facsimiles para dar\n', 'un sentido autentico a esta version electronica.  Los cinco actos\n', 'y otras interpolaciones anadidos en la edicion de Valencia (1514)\n', 'estan marcados entre comillas (").  Las unicas concesiones a la\n', 'puntuacion moderna son el uso, de vez en cuando, de la coma (,),\n', 'el punto y coma (;), y la exclamacion (!); estas tres no existen\n', 'en los facsimiles. Tampoco he podido usar el tilde a causa de los\n', 'limites de este modo de transmision, y el lector tendra que\n', 'ponerlo.  En cuanto al acento, esta transmision electronica no\n', 'permite tal cosa, pero tampoco existe en los facsimiles.\n', '\n', 'Mi sincero agradecimiento al Profesor Juan de Ca ...

# %%
# primeras 10 lineas
text[:10]
# Out:
# ['\n',
#  'LA CELESTINA\n',
#  '\n',
#  'por\n',
#  '\n',
#  'Fernando de Rojas\n',
#  '\n',
#  '(Edicion y Notas de Robert S. Rudder)\n',
#  '\n',
#  'Copyright 1998 R. S. Rudder\n']

# %%
# Cadena vacía se evalua como False
x =""
bool(x)

# %%
for i in text[:10]:
    d = i.strip()
    if d:
        print(d)
# Out:
# LA CELESTINA
# por
# Fernando de Rojas
# (Edicion y Notas de Robert S. Rudder)
# Copyright 1998 R. S. Rudder

# %%
# split()
"Hola mundo, saludos".split()
# Out:
# ['Hola', 'mundo,', 'saludos']

# %%
# startswith()
"Hola mundo, saludos".startswith('Hol')
# Out:
# True

# %%
# lower()
"Hola MUNDO, Saludos".lower()
# Out:
# 'hola mundo, saludos'

# %%
# upper()
"Hola MUNDO, Saludos".upper()
# Out:
# 'HOLA MUNDO, SALUDOS'

# %%
# replace
"Hola MUNDO, Saludos".replace("MUNDO", "Juan")
# Out:
# 'Hola Juan, Saludos'

# %% [markdown]
# # Ejercicios en clase
# - ### 1. Definir una función que calcule  el coeficiente de similitud de Jaccard para dos cadenas proporcionadas
# - ### 2. Definir una función que calcule  el coeficiente  de similitud de Dice para dos cadenas proporcionadas
# - ### 3. Definir una función que grafique el conteo de los símbolos (caracteres) dentro de un archivo proporcionado por el usuario, por ejemplo,  el libro la Celestina.txt. El conteo de los símbolos se debe ordenar de forma descendente. Considerar pasar todos los símbolos a minúsculas.

# %% [markdown]
# # Coeficiente de Jaccard
# # $$J(A,B) = \frac{|A \cap B|}{|A \cup  B|}$$

# %% [markdown]
# # Coeficiente de Dice
# # $$D(A,B) =  \frac{ 2 \times |A \cap B|}{|A| + |B|}$$

# %%
# ejemplo de cadenas por comparar
a="casuchas"
b="casitas"
coef_j = jaccard(a, b)
print("La similitud de Jaccard es: ", coef_j)
coef_d = dice(a, b)
print("La similitud de Dice es: ", coef_d)
